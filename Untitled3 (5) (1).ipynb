# %% [markdown]
# CAR PRICE PREDICTION PROJECT

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
df=pd.read_csv("used_cars.csv")
df
# Out:
#          brand                            model  model_year      milage  \
# 0         Ford  Utility Police Interceptor Base        2013  51,000 mi.
# 1      Hyundai                     Palisade SEL        2021  34,742 mi.
# 2        Lexus                    RX 350 RX 350        2022  22,372 mi.
# 3     INFINITI                 Q50 Hybrid Sport        2015  88,900 mi.
# 4         Audi        Q3 45 S line Premium Plus        2021   9,835 mi.
# ...        ...                              ...         ...         ...
# 4004   Bentley             Continental GT Speed        2023     714 mi.
# 4005      Audi             S4 3.0T Premium Plus        2022  10,900 mi.
# 4006   Porsche                           Taycan        2022   2,116 mi.
# 4007      Ford                     F-150 Raptor        2020  33,000 mi.
# 4008       BMW                     X3 xDrive30i        2020  43,000 mi.
#
#           fuel_type                                             engine  \
# ...

# %% [markdown]
# EDA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4009 entries, 0 to 4008
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   brand         4009 non-null   object
#  1   model         4009 non-null   object
#  2   model_year    4009 non-null   int64
#  3   milage        4009 non-null   object
#  4   fuel_type     3839 non-null   object
#  5   engine        4009 non-null   object
#  6   transmission  4009 non-null   object
#  7   ext_col       4009 non-null   object
#  8   int_col       4009 non-null   object
#  9   accident      3896 non-null   object
#  10  clean_title   3413 non-null   object
#  11  price         4009 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 376.0+ KB

# %%
df.describe()
# Out:
#         model_year
# count  4009.000000
# mean   2015.515590
# std       6.104816
# min    1974.000000
# 25%    2012.000000
# 50%    2017.000000
# 75%    2020.000000
# max    2024.000000

# %%
df.duplicated().sum
# Out:
# <bound method Series.sum of 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4004    False
# 4005    False
# 4006    False
# 4007    False
# 4008    False
# Length: 4009, dtype: bool>

# %%
df.nunique()
# Out:
# brand             57
# model           1898
# model_year        34
# milage          2818
# fuel_type          7
# engine          1146
# transmission      62
# ext_col          319
# int_col          156
# accident           2
# clean_title        1
# price           1569
# dtype: int64

# %%
df=df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (4009, 12)

# %%
df.nunique()
# Out:
# brand             57
# model           1898
# model_year        34
# milage          2818
# fuel_type          7
# engine          1146
# transmission      62
# ext_col          319
# int_col          156
# accident           2
# clean_title        1
# price           1569
# dtype: int64

# %%
dff=df.drop(columns=['clean_title'])

# %%
from sklearn.preprocessing import LabelEncoder
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
df=pd.read_csv("used_cars.csv")
df
df=pd.read_csv("used_cars.csv")
label_encoder1 = LabelEncoder()
label_encoder2 = LabelEncoder()
label_encoder3 = LabelEncoder()
label_encoder4 = LabelEncoder()
label_encoder5 = LabelEncoder()
label_encoder6 = LabelEncoder()
label_encoder7 = LabelEncoder()
label_encoder8 = LabelEncoder()
label_encoder9 = LabelEncoder()
label_encoder10 = LabelEncoder()
label_encoder11 = LabelEncoder()


df['model']=label_encoder1.fit_transform(df['model'])
df['brand']=label_encoder2.fit_transform(df['brand'])
df['milage']=label_encoder3.fit_transform(df['milage'])
df['fuel_type']=label_encoder4.fit_transform(df['fuel_type'])
df['transmission']=label_encoder5.fit_transform(df['transmission'])
df['engine']=label_encoder6.fit_transform(df['engine'])	
df['ext_col']=label_encoder7.fit_transform(df['ext_col'])	
df['int_col']=label_encoder8.fit_transform(df['int_col'])	
df['accident']=label_encoder9.fit_transform(df['accident'])
df['clean_title']=label_encoder10.fit_transform(df['clean_title'])
df['price']=label_encoder11.fit_transform(df['price'])

# %%
df.corr()
# Out:
#                  brand     model  model_year    milage  fuel_type    engine  \
# brand         1.000000 -0.070170    0.001970 -0.004905   0.199710 -0.066116
# model        -0.070170  1.000000    0.028237 -0.015124   0.062453 -0.037443
# model_year    0.001970  0.028237    1.000000  0.019556   0.102720  0.148065
# milage       -0.004905 -0.015124    0.019556  1.000000  -0.012341  0.044924
# fuel_type     0.199710  0.062453    0.102720 -0.012341   1.000000  0.186383
# engine       -0.066116 -0.037443    0.148065  0.044924   0.186383  1.000000
# transmission -0.005099 -0.024244    0.064506  0.005365  -0.070978 -0.011988
# ext_col      -0.002001 -0.008342   -0.036169  0.015085   0.007645 -0.037665
# int_col       0.008545  0.040801    0.035141 -0.004460   0.063728  0.023628
# accident      0.016410  0.000057    0.175604  0.004867   0.086880  0.099261
# clean_title  -0.013011  0.039634    0.264272 -0.032413   0.004811 -0.024433
# ...

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(),annot=True,cmap='Blues')
# Out:
# <Axes: >

# %%
plt.figure(figsize=(10,6))
for color,group in df.groupby('model'):
    plt.scatter(group['model'], group['price'],label=color)
plt.title('Car price by color')
plt.xlabel('Car')
plt.ylabel('price($)')
plt.legend()
plt.show()

# %% [markdown]
# #Distribution Graph

# %%
columns_to_plot=['brand','model','model_year','milage','fuel_type','engine','transmission','ext_col','int_col','accident','clean_title','price']
fig, axes=plt.subplots(nrows=len(columns_to_plot),figsize=(10,15))
#create distribution plots for each column
for i,column in enumerate(columns_to_plot):
    sns.histplot(df[column],ax=axes[i], kde=True)
    axes[i].set_title(f'Distribution of {column}')
plt.tight_layout()
plt.show()

# %% [markdown]
# #FEATURE ENGINEERING AND FEATURE SELECTION

# %%
x=df.drop(['price'],axis=1)
y=df['price']
y.shape
x
df
# Out:
#       brand  model  model_year  milage  fuel_type  engine  transmission  \
# 0        14   1743        2013    1883          1     581            16
# 1        19   1182        2021    1464          2     566            32
# 2        27   1325        2022    1043          2     541            40
# 3        20   1242        2015    2617          3     724            23
# 4         3   1225        2021    2662          2     200            32
# ...     ...    ...         ...     ...        ...     ...           ...
# 4004      5    484        2023    2323          2    1060            33
# 4005      3   1464        2022      79          2     714            59
# 4006     43   1677        2022     913          7    1133            40
# 4007     14    666        2020    1422          2     917            38
# 4008      4   1790        2020    1698          2     356            38
#
#       ext_col  int_col  accident  clean_title  price
# ...

# %%
#Scaling  of x features in training data
x=df.iloc[:,1:9].values
scaler_min = MinMaxScaler()
x_scaled=scaler_min.fit_transform(x)
x_scaled.shape
y.shape,x.shape
# Out:
# ((4009,), (4009, 8))

# %%
#read testinng file
df1=pd.read_csv("used_cars.csv")
df1=df1.drop(columns=['clean_title'])
df1['model']=label_encoder1.fit_transform(df1['model'])
df1['brand']=label_encoder2.fit_transform(df1['brand'])
df1['milage']=label_encoder3.fit_transform(df1['milage'])
df1['fuel_type']=label_encoder4.fit_transform(df1['fuel_type'])
df1['transmission']=label_encoder5.fit_transform(df1['transmission'])
df1['engine']=label_encoder6.fit_transform(df1['engine'])	
df1['ext_col']=label_encoder7.fit_transform(df1['ext_col'])	
df1['int_col']=label_encoder8.fit_transform(df1['int_col'])	
df1['accident']=label_encoder9.fit_transform(df1['accident'])
df1['price']=label_encoder11.fit_transform(df1['price'])
x_test1=df1.iloc[:,1:9].values
x_test=scaler_min.transform(x_test1)
x_test1.shape
# Out:
# (4009, 8)

# %%
x_scaled.shape
# Out:
# (4009, 8)

# %% [markdown]
# #MODEL TRAINING

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x_scaled,y,test_size=0.2,random_state=42)
x_train.shape
# Out:
# (3207, 8)

# %%
pip install tabulate
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install xgboost

# %%
import numpy as np

import pandas as pd

from tabulate import tabulate

from sklearn.metrics import mean_squared_error, r2_score

from sklearn.neighbors import KNeighborsRegressor

from sklearn. tree import DecisionTreeRegressor

from sklearn.svm import SVR

import xgboost as xgb
from xgboost import XGBRegressor

from sklearn.ensemble import RandomForestRegressor

from sklearn. linear_model import LinearRegression

regressors = {
'Linear Regression': LinearRegression(),
'K-Nearest Neighbors': KNeighborsRegressor(),
'Decision Tree': DecisionTreeRegressor(),
'Support Vector Machine': SVR(),
'Random Forest': RandomForestRegressor(random_state=42),
'xgb' : xgb.XGBRegressor (objective='reg:squarederror', random_state=42)
}
result_dict = {
'Regressor': [],
'Train_MSE' : [],
'Test_MSE' : [],
# 'Train_RMSE': [],
# 'Test_RMSE': [],
'Train_R2_Score': [],
'Test_R2_Score':[],
'Bias':[],
'Variance':[],
'Status':[]
}
max_rmse = 0.95
for reg_name,reg in regressors.items(): 
    reg.fit(x_train,y_train)
    predictions_train = reg.predict(x_train)
    predictions_test = reg. predict(x_test)
    mse_train = mean_squared_error(y_train, predictions_train)
    rmse_train = np.sqrt(mse_train)
    r2_train = r2_score(y_train, predictions_train)
    mse_test = mean_squared_error (y_test, predictions_test)
    rmse_test = np.sqrt(mse_test)
    r2_test = r2_score(y_test, predictions_test)
    result_dict[ 'Regressor'].append(reg_name)
    result_dict[ 'Train_MSE']. append(mse_train)
    result_dict['Train_R2_Score']. append(r2_train)
    result_dict[ 'Test_MSE']. append (mse_test)
    result_dict[ 'Test_R2_Score'].append(r2_test)
    bias = abs (0.95-r2_train)
    var = abs(r2_train - r2_test)
    result_dict[ 'Bias']. append (bias)
    result_dict[ 'Variance'].append(var)
    if bias > 0.1 and var > 0.1:
        status = "worst"
    elif bias > 0.1 and var < 0.1:
        status = "Underfitting"
    elif bias < 0.1 and var > 0.1:
        status = "Overfitting"
    elif bias < 0.1 and var < 0.1:
        status = "Best"
    result_dict['Status'].append(status)
Report_df = pd.DataFrame(result_dict)
print( "Final Report")
print(tabulate(Report_df, headers='keys', tablefmt='plane'))
# Out:
# Final Report
#     Regressor                 Train_MSE    Test_MSE    Train_R2_Score    Test_R2_Score       Bias    Variance  Status
# --  ----------------------  -----------  ----------  ----------------  ---------------  ---------  ----------  ------------
#  0  Linear Regression          181429        183041         0.107935        0.0553781   0.842065   0.0525565   Underfitting
#  1  K-Nearest Neighbors        127809        193197         0.371576        0.00296243  0.578424   0.368614    worst
#  2  Decision Tree                   0        269526         1              -0.390949    0.05       1.39095     Overfitting
#  3  Support Vector Machine     194112        185869         0.0455735       0.0407806   0.904427   0.00479289  Underfitting
#  4  Random Forest               19552.1      133967         0.903865        0.308635    0.0461355  0.595229    Overfitting
# ...

# %% [markdown]
# #Final output

# %%
2_scores = pd. DataFrame((df - df.mean()) / df. std())
# Set a threshold for the Z-scores (absolute value)
_score_threshold = 3 # Adjust as needed
# Identify and drop rows with outliers
outliers = (z_scores.abs() › z_score_threshold).any(axis=1)
df_no_outliers = df[~outliers]
df_no_outliers. shape
